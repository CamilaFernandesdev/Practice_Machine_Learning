# %%
#Padrão
import pandas as pd
import seaborn as sns

#Dados
from sklearn import datasets
#Máquinas de Vetores de Suporte módulo
from sklearn import svm
#Separar os dados em treinamento e teste
from sklearn.model_selection import train_test_split

# %%
iris = datasets.load_iris()
df_iris = pd.DataFrame(data=iris.data, columns=iris.feature_names)
df_iris['label'] = iris.target
df_iris['species'] = pd.Categorical.from_codes(iris.target, iris.target_names)
df_iris.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    label species
# 0      0  setosa
# 1      0  setosa
# 2      0  setosa
# 3      0  setosa
# 4      0  setosa

# %% [markdown]
# TRUQUE DE KERNEL
#
# Usar o Seaborn para identificar qual modelo, se SVM é aplicável e se os dados são lenarmente sepráveis.
# E definir qual Kernel é o melhor e reduzir processamento.

# %%
df_iris.columns
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'label', 'species'],
#       dtype='object')

# %%
#plotando em pares
sns.pairplot(df_iris[['sepal length (cm)', 'sepal width (cm)',
 'petal length (cm)', 'petal width (cm)', 'label', 'species']],
 hue='species')

# %% [markdown]
# # Classificando o Iris datasets

# %%
#Variáveis
X = iris.data
y = iris.target

#Treinamento e teste
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=13)

# %%
clf = svm.SVC(C=1.0)
clf.fit(X=X_train, y=y_train)

#Predição do cpnjunto de teste
clf.predict(X_test)
# Out:
# array([1, 1, 0, 2, 2, 0, 2, 2, 0, 1, 1, 1, 1, 0, 2, 0, 2, 2, 1, 0, 1, 0,
#        0, 2, 1, 2, 0, 2, 1, 2, 2, 0, 0, 2, 2, 1, 0, 1, 1, 0, 0, 2, 1, 2,
#        2])

# %%
#Qual classe corresponde ao conjunto de?
y_test
# Out:
# array([1, 1, 0, 2, 2, 0, 2, 2, 0, 1, 2, 2, 1, 0, 2, 0, 2, 2, 1, 0, 1, 0,
#        0, 2, 1, 2, 0, 2, 1, 2, 2, 0, 0, 2, 2, 1, 0, 1, 1, 0, 0, 2, 1, 2,
#        2])

# %%
#Resultado do modelo em %
clf.score(X_test, y_test)
# Out:
# 0.9555555555555556
